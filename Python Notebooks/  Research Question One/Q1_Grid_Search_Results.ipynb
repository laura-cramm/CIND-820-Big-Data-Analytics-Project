# %% [markdown]
# Logistic Regression

# %%
import numpy as np
import pandas as pd
import statistics
from scipy import stats

# %%
logRegScores1 = pd.read_csv("/content/logRegScores1.csv")
logRegScores2 = pd.read_csv("/content/logRegScores2.csv")
logRegScores3 = pd.read_csv("/content/logRegScores3.csv")
logRegScores4 = pd.read_csv("/content/logRegScores4.csv")
logRegScores5 = pd.read_csv("/content/logRegScores5.csv")

# %%
logRegScores1 = logRegScores1.drop(['Unnamed: 0'], axis=1)
logRegScores2 = logRegScores2.drop(['Unnamed: 0'], axis=1)
logRegScores3 = logRegScores3.drop(['Unnamed: 0'], axis=1)
logRegScores4 = logRegScores4.drop(['Unnamed: 0'], axis=1)
logRegScores5 = logRegScores5.drop(['Unnamed: 0'], axis=1)

# %%
merged_logRegA = logRegScores1.merge(logRegScores2,on=['Threshold'], suffixes=('_x1', '_x2'))
merged_logRegB = merged_logRegA.merge(logRegScores3,on=['Threshold'])
merged_logRegC = merged_logRegB.merge(logRegScores4,on=['Threshold'], suffixes=('_x3', '_x4'))
merged_logReg = merged_logRegC.merge(logRegScores5,on=['Threshold'])
merged_logReg.rename(columns={'F2_Score': 'F2_Score_x5', 'Accuracy': 'Accuracy_x5', 'Recall': 'Recall_x5', 'Precision': 'Precision_x5'}, inplace=True)

# %%
merged_logReg= merged_logReg.loc[~( (merged_logReg['Recall_x1'] == 0) | (merged_logReg['Recall_x2'] ==0)| (merged_logReg['Recall_x3'] ==0)| (merged_logReg['Recall_x4'] ==0)| (merged_logReg['Recall_x5'] ==0)| (merged_logReg['Precision_x1'] ==0)| (merged_logReg['Precision_x2'] ==0)| (merged_logReg['Precision_x3'] ==0)| (merged_logReg['Precision_x4'] ==0)| (merged_logReg['Precision_x5'] ==0)      ),:]

# %% [markdown]
# 1. Optimizing F2-Score

# %%
#Kruskal-Wallis test
f2List=[]
for i in range(len(merged_logReg['F2_Score_x1'])):
  f2List.append([merged_logReg['F2_Score_x1'].values[i], merged_logReg['F2_Score_x2'].values[i],  merged_logReg['F2_Score_x3'].values[i],  merged_logReg['F2_Score_x4'].values[i],  merged_logReg['F2_Score_x5'].values[i]])

result = stats.kruskal(*f2List)
print(result)
# Out:
# KruskalResult(statistic=3.8503311258278137, pvalue=0.5711597070362332)

# %%
#No statistically significant difference in the population medians, using default threshold of 0.5

# %% [markdown]
# 2. Optimizing Accuracy

# %%
#Kruskal-Wallis test
accuracyList=[]
for i in range(len(merged_logReg['Accuracy_x1'])):
  accuracyList.append([merged_logReg['Accuracy_x1'].values[i], merged_logReg['Accuracy_x2'].values[i],  merged_logReg['Accuracy_x3'].values[i],  merged_logReg['Accuracy_x4'].values[i],  merged_logReg['Accuracy_x5'].values[i]])

result = stats.kruskal(*accuracyList)
print(result)
# Out:
# KruskalResult(statistic=1.1218543046357623, pvalue=0.9521510676275732)

# %%
#No statistically significant difference in the population medians, using default threshold of 0.5

# %% [markdown]
# Naive Bayes

# %%
nbScores1 = pd.read_csv("/content/nbScores1.csv")
nbScores2 = pd.read_csv("/content/nbScores2.csv")
nbScores3 = pd.read_csv("/content/nbScores3.csv")
nbScores4 = pd.read_csv("/content/nbScores4.csv")
nbScores5 = pd.read_csv("/content/nbScores5.csv")

# %%
nbScores1 = nbScores1.drop(['Unnamed: 0'], axis=1)
nbScores2 = nbScores2.drop(['Unnamed: 0'], axis=1)
nbScores3 = nbScores3.drop(['Unnamed: 0'], axis=1)
nbScores4 = nbScores4.drop(['Unnamed: 0'], axis=1)
nbScores5 = nbScores5.drop(['Unnamed: 0'], axis=1)

# %%
merged_nbA = nbScores1.merge(nbScores2,on=['Threshold'], suffixes=('_x1', '_x2'))
merged_nbB = merged_nbA.merge(nbScores3,on=['Threshold'])
merged_nbC = merged_nbB.merge(nbScores4,on=['Threshold'], suffixes=('_x3', '_x4'))
merged_nb = merged_nbC.merge(nbScores5,on=['Threshold'])
merged_nb.rename(columns={'F2_Score': 'F2_Score_x5', 'Accuracy': 'Accuracy_x5', 'Recall': 'Recall_x5', 'Precision': 'Precision_x5'}, inplace=True)

# %%
merged_nb= merged_nb.loc[~( (merged_nb['Recall_x1'] == 0) | (merged_nb['Recall_x2'] ==0)| (merged_nb['Recall_x3'] ==0)| (merged_nb['Recall_x4'] ==0)| (merged_nb['Recall_x5'] ==0)| (merged_nb['Precision_x1'] ==0)| (merged_nb['Precision_x2'] ==0)| (merged_nb['Precision_x3'] ==0)| (merged_nb['Precision_x4'] ==0)| (merged_nb['Precision_x5'] ==0) |(merged_nb['Recall_x1'] == 1) | (merged_nb['Recall_x2'] ==1)| (merged_nb['Recall_x3'] ==1)| (merged_nb['Recall_x4'] ==1)| (merged_nb['Recall_x5'] ==1)| (merged_nb['Precision_x1'] ==1)| (merged_nb['Precision_x2'] ==1)| (merged_nb['Precision_x3'] ==1)| (merged_nb['Precision_x4'] ==1)| (merged_nb['Precision_x5'] ==1)       ),:]

# %% [markdown]
# 1. Optimizing F2-Score

# %%
#Kruskal-Wallis test
f2List=[]
for i in range(len(merged_nb['F2_Score_x1'])):
  f2List.append([merged_nb['F2_Score_x1'].values[i], merged_nb['F2_Score_x2'].values[i],  merged_nb['F2_Score_x3'].values[i],  merged_nb['F2_Score_x4'].values[i],  merged_nb['F2_Score_x5'].values[i]])

result = stats.kruskal(*f2List)
print(result)
# Out:
# KruskalResult(statistic=28.068571428571403, pvalue=9.120946875853627e-05)

# %%
#There is a statistically significant difference in the population medians

# %%
#Computing median F-2 Score across all five sliding windows for each combination
#of hyperparameters
for i in range(len(merged_nb['F2_Score_x1'])):
      merged_nb.loc[merged_nb.index[i], 'Median_Score'] = statistics.median([merged_nb.loc[merged_nb.index[i], 'F2_Score_x1'],merged_nb.loc[merged_nb.index[i], 'F2_Score_x2'], merged_nb.loc[merged_nb.index[i], 'F2_Score_x3'], merged_nb.loc[merged_nb.index[i], 'F2_Score_x4'], merged_nb.loc[merged_nb.index[i], 'F2_Score_x5']] )

merged_nb.sort_values("Median_Score", ascending=False, inplace=True)
merged_nb
# Out:
#    Threshold  F2_Score_x1  Accuracy_x1  Recall_x1  Precision_x1  F2_Score_x2  \
# 0        0.1     0.521568     0.342644   0.789326      0.221295     0.535901
# 1        0.2     0.506001     0.366434   0.746067      0.221241     0.520022
# 2        0.3     0.486536     0.392078   0.696348      0.220630     0.510604
# 3        0.4     0.472848     0.410616   0.662360      0.220497     0.497163
# 4        0.5     0.458166     0.430637   0.626966      0.220597     0.477062
# 5        0.6     0.444798     0.447074   0.596629      0.220423     0.449587
# 6        0.7     0.420488     0.477291   0.543539      0.220664     0.405094
#
#    Accuracy_x2  Recall_x2  Precision_x2  F2_Score_x3  ...  Precision_x3  \
# 0     0.316381   0.831561      0.221246     0.490512  ...      0.215755
# 1     0.342644   0.784835      0.221319     0.478057  ...      0.216858
# 2     0.357165   0.758534      0.221288     0.464942  ...      0.216679
# 3     0.380028   0.720761      0.221859     0.452364  ...      0.216085
# 4     0.405858   0.670957      0.221279     0.440663  ...      0.215557
# 5     0.440586   0.606603      0.220886     0.429183  ...      0.215282
# 6     0.493604   0.511752      0.220920     0.417359  ...      0.216489
#
#    F2_Score_x4  Accuracy_x4  Recall_x4  Precision_x4  F2_Score_x5  \
# 0     0.505324     0.367979   0.738986      0.223124     0.513764
# 1     0.484569     0.390657   0.689111      0.221539     0.489485
# 2     0.470198     0.413150   0.652258      0.222159     0.469949
# 3     0.455625     0.435210   0.616514      0.222924     0.448705
# 4     0.437883     0.453810   0.578554      0.221986     0.427673
# 5     0.420135     0.477229   0.539762      0.222705     0.372974
# 6     0.398839     0.506210   0.494874      0.224541     0.209313
#
#    Accuracy_x5  Recall_x5  Precision_x5  Median_Score
# 0     0.333375   0.775556      0.218603      0.513764
# 1     0.372428   0.708611      0.218820      0.489485
# 2     0.398381   0.660278      0.218274      0.470198
# 3     0.432306   0.607222      0.219500      0.455625
# 4     0.453501   0.563056      0.218004      0.440663
# 5     0.515726   0.453889      0.217722      0.429183
# 6     0.643515   0.210278      0.205539      0.405094
#
# [7 rows x 22 columns]

# %%
#Using threshold of p = 0.1

# %% [markdown]
# 2. Optimizing Accuracy

# %%
#Kruskal-Wallis test
accuracyList=[]
for i in range(len(merged_nb['Accuracy_x1'])):
  accuracyList.append([merged_nb['Accuracy_x1'].values[i], merged_nb['Accuracy_x2'].values[i],  merged_nb['Accuracy_x3'].values[i],  merged_nb['Accuracy_x4'].values[i],  merged_nb['Accuracy_x5'].values[i]])

result = stats.kruskal(*accuracyList)
print(result)
# Out:
# KruskalResult(statistic=29.361255077741983, pvalue=5.1968961820751504e-05)

# %%
#There is a statistically significant difference in the population medians

# %%
#Computing median accuracy across all five sliding windows for each combination
#of hyperparameters
for i in range(len(merged_nb['Accuracy_x1'])):
      merged_nb.loc[merged_nb.index[i], 'Median_Accuracy'] = statistics.median([merged_nb.loc[merged_nb.index[i], 'Accuracy_x1'],merged_nb.loc[merged_nb.index[i], 'Accuracy_x2'], merged_nb.loc[merged_nb.index[i], 'Accuracy_x3'], merged_nb.loc[merged_nb.index[i], 'Accuracy_x4'], merged_nb.loc[merged_nb.index[i], 'Accuracy_x5']] )

merged_nb.sort_values("Median_Accuracy", ascending=False, inplace=True)
merged_nb
# Out:
#    Threshold  F2_Score_x1  Accuracy_x1  Recall_x1  Precision_x1  F2_Score_x2  \
# 6        0.7     0.420488     0.477291   0.543539      0.220664     0.405094
# 5        0.6     0.444798     0.447074   0.596629      0.220423     0.449587
# 4        0.5     0.458166     0.430637   0.626966      0.220597     0.477062
# 3        0.4     0.472848     0.410616   0.662360      0.220497     0.497163
# 2        0.3     0.486536     0.392078   0.696348      0.220630     0.510604
# 1        0.2     0.506001     0.366434   0.746067      0.221241     0.520022
# 0        0.1     0.521568     0.342644   0.789326      0.221295     0.535901
#
#    Accuracy_x2  Recall_x2  Precision_x2  F2_Score_x3  ...  F2_Score_x4  \
# 6     0.493604   0.511752      0.220920     0.417359  ...     0.398839
# 5     0.440586   0.606603      0.220886     0.429183  ...     0.420135
# 4     0.405858   0.670957      0.221279     0.440663  ...     0.437883
# 3     0.380028   0.720761      0.221859     0.452364  ...     0.455625
# 2     0.357165   0.758534      0.221288     0.464942  ...     0.470198
# 1     0.342644   0.784835      0.221319     0.478057  ...     0.484569
# 0     0.316381   0.831561      0.221246     0.490512  ...     0.505324
#
#    Accuracy_x4  Recall_x4  Precision_x4  F2_Score_x5  Accuracy_x5  Recall_x5  \
# 6     0.506210   0.494874      0.224541     0.209313     0.643515   0.210278
# 5     0.477229   0.539762      0.222705     0.372974     0.515726   0.453889
# 4     0.453810   0.578554      0.221986     0.427673     0.453501   0.563056
# 3     0.435210   0.616514      0.222924     0.448705     0.432306   0.607222
# 2     0.413150   0.652258      0.222159     0.469949     0.398381   0.660278
# 1     0.390657   0.689111      0.221539     0.489485     0.372428   0.708611
# 0     0.367979   0.738986      0.223124     0.513764     0.333375   0.775556
#
#    Precision_x5  Median_Score  Median_Accuracy
# 6      0.205539      0.405094         0.493604
# 5      0.217722      0.429183         0.455045
# 4      0.218004      0.440663         0.441266
# 3      0.219500      0.455625         0.427795
# 2      0.218274      0.470198         0.398381
# 1      0.218820      0.489485         0.372428
# 0      0.218603      0.513764         0.342644
#
# [7 rows x 23 columns]

# %%
#Using a threshold of p=0.7

# %% [markdown]
# Random Forest

# %%
rfScores1 = pd.read_csv("/content/rfScores1.csv")
rfScores2 = pd.read_csv("/content/rfScores2.csv")
rfScores3 = pd.read_csv("/content/rfScores3.csv")
rfScores4 = pd.read_csv("/content/rfScores4.csv")
rfScores5 = pd.read_csv("/content/rfScores5.csv")

# %%
rfScores1 = rfScores1.drop(['Unnamed: 0'], axis=1)
rfScores2 = rfScores2.drop(['Unnamed: 0'], axis=1)
rfScores3 = rfScores3.drop(['Unnamed: 0'], axis=1)
rfScores4 = rfScores4.drop(['Unnamed: 0'], axis=1)
rfScores5 = rfScores5.drop(['Unnamed: 0'], axis=1)

# %%
merged_rfA = rfScores1.merge(rfScores2,on=['Threshold', 'n_Estimators', 'Max_depth'], suffixes=('_x1', '_x2'))
merged_rfB = merged_rfA.merge(rfScores3,on=['Threshold', 'n_Estimators', 'Max_depth'])
merged_rfC = merged_rfB.merge(rfScores4,on=['Threshold', 'n_Estimators', 'Max_depth'], suffixes=('_x3', '_x4'))
merged_rf = merged_rfC.merge(rfScores5,on=['Threshold', 'n_Estimators', 'Max_depth'])
merged_rf.rename(columns={'F2_Score': 'F2_Score_x5', 'Accuracy': 'Accuracy_x5', 'Recall': 'Recall_x5', 'Precision': 'Precision_x5'}, inplace=True)

# %%
merged_rf= merged_rf.loc[~( (merged_rf['Recall_x1'] == 0) | (merged_rf['Recall_x2'] ==0)| (merged_rf['Recall_x3'] ==0)| (merged_rf['Recall_x4'] ==0)| (merged_rf['Recall_x5'] ==0)| (merged_rf['Precision_x1'] ==0)| (merged_rf['Precision_x2'] ==0)| (merged_rf['Precision_x3'] ==0)| (merged_rf['Precision_x4'] ==0)| (merged_rf['Precision_x5'] ==0) |(merged_rf['Recall_x1'] == 1) | (merged_rf['Recall_x2'] ==1)| (merged_rf['Recall_x3'] ==1)| (merged_rf['Recall_x4'] ==1)| (merged_rf['Recall_x5'] ==1)| (merged_rf['Precision_x1'] ==1)| (merged_rf['Precision_x2'] ==1)| (merged_rf['Precision_x3'] ==1)| (merged_rf['Precision_x4'] ==1)| (merged_rf['Precision_x5'] ==1)       ),:]

# %% [markdown]
# 1. Optimizing F2-Score

# %%
#Kruskal-Wallis test
f2List=[]
for i in range(len(merged_rf['F2_Score_x1'])):
  f2List.append([merged_rf['F2_Score_x1'].values[i], merged_rf['F2_Score_x2'].values[i],  merged_rf['F2_Score_x3'].values[i],  merged_rf['F2_Score_x4'].values[i],  merged_rf['F2_Score_x5'].values[i]])

result = stats.kruskal(*f2List)
print(result)
# Out:
# KruskalResult(statistic=182.41819411268503, pvalue=4.299045231257259e-19)

# %%
#There is a statistically significant difference in the population medians

# %%
#Computing median F-2 Score across all five sliding windows for each combination
#of hyperparameters
for i in range(len(merged_rf['F2_Score_x1'])):
      merged_rf.loc[merged_rf.index[i], 'Median_Score'] = statistics.median([merged_rf.loc[merged_rf.index[i], 'F2_Score_x1'],merged_rf.loc[merged_rf.index[i], 'F2_Score_x2'], merged_rf.loc[merged_rf.index[i], 'F2_Score_x3'], merged_rf.loc[merged_rf.index[i], 'F2_Score_x4'], merged_rf.loc[merged_rf.index[i], 'F2_Score_x5']] )

merged_rf.sort_values("Median_Score", ascending=False, inplace=True)
merged_rf

#The optimal hyperparameters are n_Estimators=75, max_depth=3, and threshold=0.4
# Out:
#      n_Estimators  Max_depth  Threshold  F2_Score_x1  Accuracy_x1  Recall_x1  \
# 129            75          3        0.4     0.583907     0.221467   0.996348
# 183           100          3        0.4     0.583556     0.221961   0.995225
# 75             50          3        0.4     0.582745     0.223012   0.992697
# 21             25          3        0.4     0.582689     0.224866   0.991292
# 138            75          4        0.4     0.577738     0.236792   0.972191
# 84             50          4        0.4     0.575955     0.243033   0.964045
# 209           100         10        0.3     0.564596     0.266576   0.923876
# 192           100          4        0.4     0.572803     0.243713   0.956742
# 101            50         10        0.3     0.565915     0.267812   0.925843
# 155            75         10        0.3     0.566209     0.264104   0.928933
# 30             25          4        0.4     0.568880     0.252858   0.942135
# 47             25         10        0.3     0.557871     0.289192   0.894944
# 93             50          5        0.4     0.561560     0.276896   0.910674
# 147            75          5        0.4     0.555536     0.286103   0.892135
# 39             25          5        0.4     0.553345     0.281715   0.890449
# 201           100          5        0.4     0.551080     0.296731   0.876124
# 102            50         10        0.4     0.311523     0.587716   0.346910
# %%
#Kruskal-Wallis test
accuracyList=[]
for i in range(len(merged_rf['Accuracy_x1'])):
  accuracyList.append([merged_rf['Accuracy_x1'].values[i], merged_rf['Accuracy_x2'].values[i],  merged_rf['Accuracy_x3'].values[i],  merged_rf['Accuracy_x4'].values[i],  merged_rf['Accuracy_x5'].values[i]])

result = stats.kruskal(*accuracyList)
print(result)
# Out:
# KruskalResult(statistic=184.3336147821486, pvalue=2.0378763514991343e-19)

# %%
#There is a statistically significant difference in the population medians

# %%
#Computing median accuracy across all five sliding windows for each combination
#of hyperparameters
for i in range(len(merged_rf['Accuracy_x1'])):
      merged_rf.loc[merged_rf.index[i], 'Median_Accuracy'] = statistics.median([merged_rf.loc[merged_rf.index[i], 'Accuracy_x1'],merged_rf.loc[merged_rf.index[i], 'Accuracy_x2'], merged_rf.loc[merged_rf.index[i], 'Accuracy_x3'], merged_rf.loc[merged_rf.index[i], 'Accuracy_x4'], merged_rf.loc[merged_rf.index[i], 'Accuracy_x5']] )

merged_rf.sort_values("Median_Accuracy", ascending=False, inplace=True)
merged_rf

#Optimal hyperparameters are n_Estimators=75, max_depth=10, Threshold=0.5
# Out:
#      n_Estimators  Max_depth  Threshold  F2_Score_x1  Accuracy_x1  Recall_x1  \
# 157            75         10        0.5     0.005597     0.778718   0.004494
# 211           100         10        0.5     0.003156     0.779954   0.002528
# 49             25         10        0.5     0.020727     0.772972   0.016854
# 103            50         10        0.5     0.010109     0.777235   0.008146
# 148            75          5        0.5     0.025363     0.767657   0.020787
# 202           100          5        0.5     0.045127     0.759068   0.037640
# 40             25          5        0.5     0.142421     0.706606   0.130899
# 31             25          4        0.5     0.113456     0.729284   0.100562
# 94             50          5        0.5     0.136254     0.714453   0.123876
# 139            75          4        0.5     0.094765     0.737749   0.082584
# 193           100          4        0.5     0.136788     0.714083   0.124438
# 13             25          2        0.5     0.312898     0.600012   0.344663
# 85             50          4        0.5     0.131432     0.715628   0.119101
# 76             50          3        0.5     0.292842     0.615770   0.314888
# 22             25          3        0.5     0.326179     0.580980   0.367978
# 130            75          3        0.5     0.195931     0.674597   0.190449
# 184           100          3        0.5     0.258091     0.632577   0.268820
# 121            75          2        0.5     0.342208     0.568189   0.393539
# 67             50          2        0.5     0.367759     0.550022   0.435112
# 175           100          2        0.5     0.378820     0.536118   0.456180
# 4              25          1        0.5     0.407076     0.504789   0.510674
# 58             50          1        0.5     0.407459     0.499104   0.513764
# 166           100          1        0.5     0.406724     0.504233   0.510393
# 112            75          1        0.5     0.396613     0.511648   0.492135
# 48             25         10        0.4     0.304955     0.588024   0.338483
# 156            75         10        0.4     0.310490     0.591485   0.344382
# 210           100         10        0.4     0.291219     0.612927   0.313764
# 102            50         10        0.4     0.311523     0.587716   0.346910
# 201           100          5        0.4     0.551080     0.296731   0.876124
# 39             25          5        0.4     0.553345     0.281715   0.890449
# 147            75          5        0.4     0.555536     0.286103   0.892135
# 93             50          5        0.4     0.561560     0.276896   0.910674
# 47             25         10        0.3     0.557871     0.289192   0.894944
# 30             25          4        0.4     0.568880     0.252858   0.942135
# 138            75          4        0.4     0.577738     0.236792   0.972191
# 211   0.001111      0.117647      0.009708         0.774887
# 49    0.013889      0.171233      0.039428         0.760180
# 103   0.006389      0.201754      0.073879         0.741272
# 148   0.001389      0.200000      0.146319         0.702342
# 202   0.001389      0.200000      0.162087         0.691034
# 40    0.008333      0.204082      0.188363         0.673670
# 31    0.014444      0.238532      0.195961         0.664277
# 94    0.008889      0.203822      0.236568         0.642094
# 139   0.004722      0.200000      0.236107         0.637521
# 193   0.001944      0.184211      0.257721         0.621702
# 13    0.155833      0.216686      0.311728         0.600012
# 85    0.018611      0.235088      0.288584         0.596984
# 76    0.072500      0.217500      0.309104         0.581289
# 22    0.005000      0.202247      0.326179         0.580980
# 130   0.016111      0.210909      0.332118         0.575110
# 184   0.006389      0.225490      0.322023         0.564358
# 121   0.080556      0.217881      0.342208         0.563987
# 67    0.131389      0.223429      0.348152         0.561824
# 175   0.013056      0.231527      0.370967         0.536118
# 4     0.138333      0.205192      0.372782         0.534326
# 58    0.135000      0.227955      0.366397         0.533399
# 166   0.024444      0.219451      0.361449         0.524686
# 112   0.024167      0.213235      0.376764         0.519867
# 48    0.293333      0.225352      0.401850         0.513316
# 156   0.177222      0.223155      0.440975         0.470926
# 210   0.190833      0.223124      0.443917         0.462770
# 102   0.200556      0.218523      0.453652         0.441513
# 201   0.651667      0.220468      0.551080         0.293394
# 39    0.661667      0.218873      0.553345         0.288080
# 147   0.635833      0.220712      0.555536         0.286103
# 93    0.681944      0.220002      0.561560         0.276896
# 47    0.817500      0.220449      0.564779         0.268059
# 30    0.841944      0.220693      0.567618         0.256874
# 138   0.834444      0.221175      0.576962         0.249768
# 192   0.832500      0.220676      0.572803         0.247173
# 84    0.831944      0.221983      0.574803         0.245814
# 101   0.753611      0.220479      0.572276         0.239078
# 155   0.741944      0.219944      0.572195         0.238275
# 209   0.770000      0.221778      0.574124         0.236112
# 21    0.952222      0.222049      0.580675         0.230365
# 129   0.942500      0.221953      0.583907         0.229747
# 75    0.970000      0.221841      0.582745         0.228882
# 183   0.945000      0.222179      0.583556         0.228141
#
# [44 rows x 25 columns]

# %% [markdown]
# Light GBM

# %%
bstScores1 = pd.read_csv("/content/bstScores1.csv")
bstScores2 = pd.read_csv("/content/bstScores2.csv")
bstScores3 = pd.read_csv("/content/bstScores3.csv")
bstScores4 = pd.read_csv("/content/bstScores4.csv")
bstScores5 = pd.read_csv("/content/bstScores5.csv")

# %%
bstScores1 = bstScores1.drop(['Unnamed: 0'], axis=1)
bstScores2 = bstScores2.drop(['Unnamed: 0'], axis=1)
bstScores3 = bstScores3.drop(['Unnamed: 0'], axis=1)
bstScores4 = bstScores4.drop(['Unnamed: 0'], axis=1)
bstScores5 = bstScores5.drop(['Unnamed: 0'], axis=1)

# %%
merged_bstA = bstScores1.merge(bstScores2,on=['Threshold', 'Num_Leaves', 'Reg_Alpha', 'Reg_Lambda', 'Min_Data'], suffixes=('_x1', '_x2'))
merged_bstB = merged_bstA.merge(bstScores3,on=['Threshold', 'Num_Leaves', 'Reg_Alpha', 'Reg_Lambda', 'Min_Data'])
merged_bstC = merged_bstB.merge(bstScores4,on=['Threshold', 'Num_Leaves', 'Reg_Alpha', 'Reg_Lambda', 'Min_Data'], suffixes=('_x3', '_x4'))
merged_bst = merged_bstC.merge(bstScores5,on=['Threshold', 'Num_Leaves', 'Reg_Alpha', 'Reg_Lambda', 'Min_Data'])
merged_bst.rename(columns={'F2_Score': 'F2_Score_x5', 'Accuracy': 'Accuracy_x5', 'Recall': 'Recall_x5', 'Precision': 'Precision_x5'}, inplace=True)

# %%
merged_bst= merged_bst.loc[~( (merged_bst['Recall_x1'] == 0) | (merged_bst['Recall_x2'] ==0)| (merged_bst['Recall_x3'] ==0)| (merged_bst['Recall_x4'] ==0)| (merged_bst['Recall_x5'] ==0)| (merged_bst['Precision_x1'] ==0)| (merged_bst['Precision_x2'] ==0)| (merged_bst['Precision_x3'] ==0)| (merged_bst['Precision_x4'] ==0)| (merged_bst['Precision_x5'] ==0) |(merged_bst['Recall_x1'] == 1) | (merged_bst['Recall_x2'] ==1)| (merged_bst['Recall_x3'] ==1)| (merged_bst['Recall_x4'] ==1)| (merged_bst['Recall_x5'] ==1)| (merged_bst['Precision_x1'] ==1)| (merged_bst['Precision_x2'] ==1)| (merged_bst['Precision_x3'] ==1)| (merged_bst['Precision_x4'] ==1)| (merged_bst['Precision_x5'] ==1)       ),:]

# %% [markdown]
# 1. Optimizing F2-Score

# %%
#Kruskal-Wallis test
f2List=[]
for i in range(len(merged_bst['F2_Score_x1'])):
  f2List.append([merged_bst['F2_Score_x1'].values[i], merged_bst['F2_Score_x2'].values[i],  merged_bst['F2_Score_x3'].values[i],  merged_bst['F2_Score_x4'].values[i],  merged_bst['F2_Score_x5'].values[i]])

result = stats.kruskal(*f2List)
print(result)
# Out:
# KruskalResult(statistic=399.7930493918315, pvalue=1.191306136479121e-39)

# %%
#There is a statistically significant difference in the population medians

# %%
#Computing median F-2 Score across all five sliding windows for each combination
#of hyperparameters
for i in range(len(merged_bst['F2_Score_x1'])):
      merged_bst.loc[merged_bst.index[i], 'Median_Score'] = statistics.median([merged_bst.loc[merged_bst.index[i], 'F2_Score_x1'],merged_bst.loc[merged_bst.index[i], 'F2_Score_x2'], merged_bst.loc[merged_bst.index[i], 'F2_Score_x3'], merged_bst.loc[merged_bst.index[i], 'F2_Score_x4'], merged_bst.loc[merged_bst.index[i], 'F2_Score_x5']] )

merged_bst.sort_values("Median_Score", ascending=False, inplace=True)
merged_bst

#The optimal hyperparameters are num_leaves=31, reg_alpha=0.5, reg_lambda=0.5, min_data=30, and threshold=0.1
# Out:
#      Num_Leaves  Reg_Alpha  Reg_Lambda  Min_Data  Threshold  F2_Score_x1  \
# 198          31        0.5         0.5        30        0.1     0.475343
# 180          31        0.5         0.1       100        0.1     0.525927
# 171          31        0.5         0.1        30        0.1     0.468503
# 207          31        0.5         0.5       100        0.1     0.516760
# 153          31        0.1         0.5       100        0.1     0.514381
# ..          ...        ...         ...       ...        ...          ...
# 202          31        0.5         0.5        30        0.5     0.011829
# 184          31        0.5         0.1       100        0.5     0.002451
# 130          31        0.1         0.1       100        0.5     0.003501
# 121          31        0.1         0.1        30        0.5     0.011827
# 194          31        0.5         0.5         5        0.6     0.003151
#
#      Accuracy_x1  Recall_x1  Precision_x1  F2_Score_x2  ...  Precision_x3  \
# 198     0.408700   0.667697      0.220849     0.566508  ...      0.217313
# 180     0.337885   0.800562      0.221704     0.559295  ...      0.216952
# 171     0.422048   0.648876      0.221838     0.560744  ...      0.216774
# 207     0.343756   0.779494      0.220063     0.559761  ...      0.216476
# 153     0.349441   0.771629      0.220430     0.563346  ...      0.217044
# ..           ...        ...           ...          ...  ...           ...
# 202     0.776123   0.009551      0.259542     0.002789  ...      0.285714
# 184     0.778595   0.001966      0.189189     0.006255  ...      0.500000
# 130     0.778657   0.002809      0.238095     0.004174  ...      0.500000
# 121     0.775938   0.009551      0.253731     0.003827  ...      0.210526
# 194     0.778718   0.002528      0.230769     0.009368  ...      0.200000
#
#      F2_Score_x4  Accuracy_x4  Recall_x4  Precision_x4  F2_Score_x5  \
# 198     0.585299     0.228141   0.987531      0.222611     0.586432
# 180     0.586518     0.227214   0.990856      0.222818     0.585596
# 171     0.586167     0.229315   0.988640      0.223014     0.586226
# 207     0.587917     0.227276   0.993904      0.223211     0.586575
# 153     0.587695     0.228573   0.992519      0.223331     0.582697
# ..           ...          ...        ...           ...          ...
# 202     0.006885     0.773960   0.005542      0.224719     0.070565
# 184     0.029708     0.764691   0.024383      0.234667     0.078302
# 130     0.035157     0.759254   0.029094      0.211268     0.079853
# 121     0.002764     0.775752   0.002217      0.222222     0.069263
# 194     0.000346     0.776803   0.000277      0.200000     0.021111
#
#      Accuracy_x5  Recall_x5  Precision_x5  Median_Score
# 198     0.224866   0.993611      0.222202      0.579274
# 180     0.227832   0.989722      0.222382      0.578297
# 171     0.227028   0.991667      0.222444      0.576878
# 207     0.226534   0.992778      0.222471      0.576456
# 153     0.232713   0.980000      0.222264      0.576088
# ..           ...        ...           ...           ...
# 202     0.748316   0.060000      0.238674      0.006885
# 184     0.742384   0.067222      0.229820      0.006255
# 130     0.742199   0.068611      0.231707      0.004174
# 121     0.747884   0.058889      0.234513      0.003827
# 194     0.767657   0.017222      0.218310      0.003151
#
# [94 rows x 26 columns]

# %% [markdown]
# 2. Optimizing Accuracy

# %%
#Kruskal-Wallis test
accuracyList=[]
for i in range(len(merged_bst['Accuracy_x1'])):
  accuracyList.append([merged_bst['Accuracy_x1'].values[i], merged_bst['Accuracy_x2'].values[i],  merged_bst['Accuracy_x3'].values[i],  merged_bst['Accuracy_x4'].values[i],  merged_bst['Accuracy_x5'].values[i]])

result = stats.kruskal(*accuracyList)
print(result)
# Out:
# KruskalResult(statistic=396.4346040542211, pvalue=4.361849856158313e-39)

# %%
#There is a statistically significant difference in the population medians

# %%
#Computing median accuracy across all five sliding windows for each combination
#of hyperparameters
for i in range(len(merged_bst['Accuracy_x1'])):
      merged_bst.loc[merged_bst.index[i], 'Median_Accuracy'] = statistics.median([merged_bst.loc[merged_bst.index[i], 'Accuracy_x1'],merged_bst.loc[merged_bst.index[i], 'Accuracy_x2'], merged_bst.loc[merged_bst.index[i], 'Accuracy_x3'], merged_bst.loc[merged_bst.index[i], 'Accuracy_x4'], merged_bst.loc[merged_bst.index[i], 'Accuracy_x5']] )

merged_bst.sort_values("Median_Accuracy", ascending=False, inplace=True)
merged_bst

#The optimal hyperparameters are num_leaves=31, reg_alpha=0.5, reg_lambda=0.5, min_data=5, and threshold=0.6
# Out:
#      Num_Leaves  Reg_Alpha  Reg_Lambda  Min_Data  Threshold  F2_Score_x1  \
# 194          31        0.5         0.5         5        0.6     0.003151
# 202          31        0.5         0.5        30        0.5     0.011829
# 113          31        0.1         0.1         5        0.6     0.006972
# 130          31        0.1         0.1       100        0.5     0.003501
# 121          31        0.1         0.1        30        0.5     0.011827
# ..          ...        ...         ...       ...        ...          ...
# 126          31        0.1         0.1       100        0.1     0.509958
# 198          31        0.5         0.5        30        0.1     0.475343
# 180          31        0.5         0.1       100        0.1     0.525927
# 162          31        0.5         0.1         5        0.1     0.473617
# 207          31        0.5         0.5       100        0.1     0.516760
#
#      Accuracy_x1  Recall_x1  Precision_x1  F2_Score_x2  ...  F2_Score_x4  \
# 194     0.778718   0.002528      0.230769     0.009368  ...     0.000346
# 202     0.776123   0.009551      0.259542     0.002789  ...     0.006885
# 113     0.776123   0.005618      0.194175     0.012105  ...     0.000692
# 130     0.778657   0.002809      0.238095     0.004174  ...     0.035157
# 121     0.775938   0.009551      0.253731     0.003827  ...     0.002764
# ..           ...        ...           ...          ...  ...          ...
# 126     0.353457   0.760955      0.219869     0.561622  ...     0.587762
# 198     0.408700   0.667697      0.220849     0.566508  ...     0.585299
# 180     0.337885   0.800562      0.221704     0.559295  ...     0.586518
# 162     0.408886   0.664607      0.220339     0.562994  ...     0.587869
# 207     0.343756   0.779494      0.220063     0.559761  ...     0.587917
#
#      Accuracy_x4  Recall_x4  Precision_x4  F2_Score_x5  Accuracy_x5  \
# 194     0.776803   0.000277      0.200000     0.021111     0.767657
# 202     0.773960   0.005542      0.224719     0.070565     0.748316
# 113     0.776308   0.000554      0.133333     0.022425     0.766174
# 130     0.759254   0.029094      0.211268     0.079853     0.742199
# 121     0.775752   0.002217      0.222222     0.069263     0.747884
# ..           ...        ...           ...          ...          ...
# 126     0.229191   0.992242      0.223435     0.585763     0.226349
# 198     0.228141   0.987531      0.222611     0.586432     0.224866
# 180     0.227214   0.990856      0.222818     0.585596     0.227832
# 162     0.226719   0.994181      0.223120     0.588322     0.223692
# 207     0.227276   0.993904      0.223211     0.586575     0.226534
#
#      Recall_x5  Precision_x5  Median_Score  Median_Accuracy
# 194   0.017222      0.218310      0.003151         0.776803
# 202   0.060000      0.238674      0.006885         0.776123
# 113   0.018333      0.208861      0.006972         0.776123
# 130   0.068611      0.231707      0.004174         0.775876
# 121   0.058889      0.234513      0.003827         0.775814
# ..         ...           ...           ...              ...
# 126   0.991111      0.222222      0.575220         0.229191
# 198   0.993611      0.222202      0.579274         0.228141
# 180   0.989722      0.222382      0.578297         0.227832
# 162   0.998611      0.222559      0.574132         0.227646
# 207   0.992778      0.222471      0.576456         0.227276
#
# [94 rows x 27 columns]
