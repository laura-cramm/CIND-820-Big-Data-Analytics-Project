# %% [markdown]
# Logistic Regression

# %%
import numpy as np
import pandas as pd
import statistics
from scipy import stats

# %%
logRegScores1 = pd.read_csv("/content/logRegScores1.csv")
logRegScores2 = pd.read_csv("/content/logRegScores2.csv")
logRegScores3 = pd.read_csv("/content/logRegScores3.csv")
logRegScores4 = pd.read_csv("/content/logRegScores4.csv")
logRegScores5 = pd.read_csv("/content/logRegScores5.csv")

# %%
logRegScores1 = logRegScores1.drop(['Unnamed: 0'], axis=1)
logRegScores2 = logRegScores2.drop(['Unnamed: 0'], axis=1)
logRegScores3 = logRegScores3.drop(['Unnamed: 0'], axis=1)
logRegScores4 = logRegScores4.drop(['Unnamed: 0'], axis=1)
logRegScores5 = logRegScores5.drop(['Unnamed: 0'], axis=1)

# %%
merged_logRegA = logRegScores1.merge(logRegScores2,on=['Threshold'], suffixes=('_x1', '_x2'))
merged_logRegB = merged_logRegA.merge(logRegScores3,on=['Threshold'])
merged_logRegC = merged_logRegB.merge(logRegScores4,on=['Threshold'], suffixes=('_x3', '_x4'))
merged_logReg = merged_logRegC.merge(logRegScores5,on=['Threshold'])
merged_logReg.rename(columns={'F2_Score': 'F2_Score_x5', 'Accuracy': 'Accuracy_x5', 'Recall': 'Recall_x5', 'Precision': 'Precision_x5'}, inplace=True)

# %%
merged_logReg= merged_logReg.loc[~( (merged_logReg['Recall_x1'] == 0) | (merged_logReg['Recall_x2'] ==0)| (merged_logReg['Recall_x3'] ==0)| (merged_logReg['Recall_x4'] ==0)| (merged_logReg['Recall_x5'] ==0)| (merged_logReg['Precision_x1'] ==0)| (merged_logReg['Precision_x2'] ==0)| (merged_logReg['Precision_x3'] ==0)| (merged_logReg['Precision_x4'] ==0)| (merged_logReg['Precision_x5'] ==0)        ),:]

# %% [markdown]
# 1. Optimizing F2-Score

# %%
#Kruskal-Wallis test
f2List=[]
for i in range(len(merged_logReg['F2_Score_x1'])):
  f2List.append([merged_logReg['F2_Score_x1'].values[i], merged_logReg['F2_Score_x2'].values[i],  merged_logReg['F2_Score_x3'].values[i],  merged_logReg['F2_Score_x4'].values[i],  merged_logReg['F2_Score_x5'].values[i]])

result = stats.kruskal(*f2List)
print(result)
# Out:
# KruskalResult(statistic=11.693457943925234, pvalue=0.019782492371891558)

# %%
#There is a statistically significant difference in the population medians

# %%
#Computing median F-2 Score across all five sliding windows for each combination
#of hyperparameters
for i in range(len(merged_logReg['F2_Score_x1'])):
      merged_logReg.loc[merged_logReg.index[i], 'Median_Score'] = statistics.median([merged_logReg.loc[merged_logReg.index[i], 'F2_Score_x1'],merged_logReg.loc[merged_logReg.index[i], 'F2_Score_x2'], merged_logReg.loc[merged_logReg.index[i], 'F2_Score_x3'], merged_logReg.loc[merged_logReg.index[i], 'F2_Score_x4'], merged_logReg.loc[merged_logReg.index[i], 'F2_Score_x5']] )

merged_logReg.sort_values("Median_Score", ascending=False, inplace=True)
merged_logReg

#Use threshold of 0.1
# Out:
#    Threshold  F2_Score_x1  Accuracy_x1  Recall_x1  Precision_x1  F2_Score_x2  \
# 0        0.1     0.474794     0.153119   1.000000      0.153119     0.487225
# 1        0.2     0.474794     0.153119   1.000000      0.153119     0.487225
# 2        0.3     0.474794     0.153119   1.000000      0.153119     0.487225
# 3        0.4     0.471964     0.168775   0.980754      0.153479     0.487243
# 4        0.5     0.343488     0.504973   0.496391      0.153884     0.395334
#
#    Accuracy_x2  Recall_x2  Precision_x2  F2_Score_x3  ...  Precision_x3  \
# 0     0.159688   1.000000      0.159688     0.484932  ...       0.15846
# 1     0.159688   1.000000      0.159688     0.484932  ...       0.15846
# 2     0.159688   1.000000      0.159688     0.484932  ...       0.15846
# 3     0.159750   1.000000      0.159698     0.484950  ...       0.15847
# 4     0.408951   0.629373      0.158932     0.278153  ...       0.16593
#
#    F2_Score_x4  Accuracy_x4  Recall_x4  Precision_x4  F2_Score_x5  \
# 0     0.478437     0.155022   1.000000      0.155022     0.481350
# 1     0.478437     0.155022   1.000000      0.155022     0.481350
# 2     0.478437     0.155022   1.000000      0.155022     0.481350
# 3     0.478437     0.155022   1.000000      0.155022     0.481350
# 4     0.322618     0.535241   0.444356      0.153931     0.397009
#
#    Accuracy_x5  Recall_x5  Precision_x5  Median_Score
# 0     0.156557   1.000000      0.156557      0.481350
# 1     0.156557   1.000000      0.156557      0.481350
# 2     0.156557   1.000000      0.156557      0.481350
# 3     0.156557   1.000000      0.156557      0.481350
# 4     0.395813   0.647451      0.155858      0.343488
#
# [5 rows x 22 columns]

# %% [markdown]
# 2. Optimizing Accuracy

# %%
#Kruskal-Wallis test
accuracyList=[]
for i in range(len(merged_logReg['Accuracy_x1'])):
  accuracyList.append([merged_logReg['Accuracy_x1'].values[i], merged_logReg['Accuracy_x2'].values[i],  merged_logReg['Accuracy_x3'].values[i],  merged_logReg['Accuracy_x4'].values[i],  merged_logReg['Accuracy_x5'].values[i]])

result = stats.kruskal(*accuracyList)
print(result)
# Out:
# KruskalResult(statistic=13.03925233644862, pvalue=0.011085584114449034)

# %%
#There is a statistically significant difference in the population medians

# %%
#Computing median accuracy across all five sliding windows for each combination
#of hyperparameters
for i in range(len(merged_logReg['Accuracy_x1'])):
      merged_logReg.loc[merged_logReg.index[i], 'Median_Accuracy'] = statistics.median([merged_logReg.loc[merged_logReg.index[i], 'Accuracy_x1'],merged_logReg.loc[merged_logReg.index[i], 'Accuracy_x2'], merged_logReg.loc[merged_logReg.index[i], 'Accuracy_x3'], merged_logReg.loc[merged_logReg.index[i], 'Accuracy_x4'], merged_logReg.loc[merged_logReg.index[i], 'Accuracy_x5']] )

merged_logReg.sort_values("Median_Accuracy", ascending=False, inplace=True)
merged_logReg

#Use default threshold of 0.5
# Out:
#    Threshold  F2_Score_x1  Accuracy_x1  Recall_x1  Precision_x1  F2_Score_x2  \
# 4        0.5     0.343488     0.504973   0.496391      0.153884     0.395334
# 3        0.4     0.471964     0.168775   0.980754      0.153479     0.487243
# 0        0.1     0.474794     0.153119   1.000000      0.153119     0.487225
# 1        0.2     0.474794     0.153119   1.000000      0.153119     0.487225
# 2        0.3     0.474794     0.153119   1.000000      0.153119     0.487225
#
#    Accuracy_x2  Recall_x2  Precision_x2  F2_Score_x3  ...  F2_Score_x4  \
# 4     0.408951   0.629373      0.158932     0.278153  ...     0.322618
# 3     0.159750   1.000000      0.159698     0.484950  ...     0.478437
# 0     0.159688   1.000000      0.159688     0.484932  ...     0.478437
# 1     0.159688   1.000000      0.159688     0.484932  ...     0.478437
# 2     0.159688   1.000000      0.159688     0.484932  ...     0.478437
#
#    Accuracy_x4  Recall_x4  Precision_x4  F2_Score_x5  Accuracy_x5  Recall_x5  \
# 4     0.535241   0.444356      0.153931     0.397009     0.395813   0.647451
# 3     0.155022   1.000000      0.155022     0.481350     0.156557   1.000000
# 0     0.155022   1.000000      0.155022     0.481350     0.156557   1.000000
# 1     0.155022   1.000000      0.155022     0.481350     0.156557   1.000000
# 2     0.155022   1.000000      0.155022     0.481350     0.156557   1.000000
#
#    Precision_x5  Median_Score  Median_Accuracy
# 4      0.155858      0.343488         0.504973
# 3      0.156557      0.481350         0.158522
# 0      0.156557      0.481350         0.156557
# 1      0.156557      0.481350         0.156557
# 2      0.156557      0.481350         0.156557
#
# [5 rows x 23 columns]

# %% [markdown]
# Naive Bayes

# %%
nbScores1 = pd.read_csv("/content/nbScores1.csv")
nbScores2 = pd.read_csv("/content/nbScores2.csv")
nbScores3 = pd.read_csv("/content/nbScores3.csv")
nbScores4 = pd.read_csv("/content/nbScores4.csv")
nbScores5 = pd.read_csv("/content/nbScores5.csv")

# %%
nbScores1 = nbScores1.drop(['Unnamed: 0'], axis=1)
nbScores2 = nbScores2.drop(['Unnamed: 0'], axis=1)
nbScores3 = nbScores3.drop(['Unnamed: 0'], axis=1)
nbScores4 = nbScores4.drop(['Unnamed: 0'], axis=1)
nbScores5 = nbScores5.drop(['Unnamed: 0'], axis=1)

# %%
merged_nbA = nbScores1.merge(nbScores2,on=['Threshold'], suffixes=('_x1', '_x2'))
merged_nbB = merged_nbA.merge(nbScores3,on=['Threshold'])
merged_nbC = merged_nbB.merge(nbScores4,on=['Threshold'], suffixes=('_x3', '_x4'))
merged_nb = merged_nbC.merge(nbScores5,on=['Threshold'])
merged_nb.rename(columns={'F2_Score': 'F2_Score_x5', 'Accuracy': 'Accuracy_x5', 'Recall': 'Recall_x5', 'Precision': 'Precision_x5'}, inplace=True)

# %%
merged_nb= merged_nb.loc[~( (merged_nb['Recall_x1'] == 0) | (merged_nb['Recall_x2'] ==0)| (merged_nb['Recall_x3'] ==0)| (merged_nb['Recall_x4'] ==0)| (merged_nb['Recall_x5'] ==0)| (merged_nb['Precision_x1'] ==0)| (merged_nb['Precision_x2'] ==0)| (merged_nb['Precision_x3'] ==0)| (merged_nb['Precision_x4'] ==0)| (merged_nb['Precision_x5'] ==0) |(merged_nb['Recall_x1'] == 1) | (merged_nb['Recall_x2'] ==1)| (merged_nb['Recall_x3'] ==1)| (merged_nb['Recall_x4'] ==1)| (merged_nb['Recall_x5'] ==1)| (merged_nb['Precision_x1'] ==1)| (merged_nb['Precision_x2'] ==1)| (merged_nb['Precision_x3'] ==1)| (merged_nb['Precision_x4'] ==1)| (merged_nb['Precision_x5'] ==1)       ),:]

# %% [markdown]
# 1. Optimizing F2-Score

# %%
#Kruskal-Wallis test
f2List=[]
for i in range(len(merged_nb['F2_Score_x1'])):
  f2List.append([merged_nb['F2_Score_x1'].values[i], merged_nb['F2_Score_x2'].values[i],  merged_nb['F2_Score_x3'].values[i],  merged_nb['F2_Score_x4'].values[i],  merged_nb['F2_Score_x5'].values[i]])

result = stats.kruskal(*f2List)
print(result)
# Out:
# KruskalResult(statistic=9.806769230769234, pvalue=0.043811507608028925)

# %%
#There is a statistically significant difference in the population medians

# %%
#Computing median F-2 Score across all five sliding windows for each combination
#of hyperparameters
for i in range(len(merged_nb['F2_Score_x1'])):
      merged_nb.loc[merged_nb.index[i], 'Median_Score'] = statistics.median([merged_nb.loc[merged_nb.index[i], 'F2_Score_x1'],merged_nb.loc[merged_nb.index[i], 'F2_Score_x2'], merged_nb.loc[merged_nb.index[i], 'F2_Score_x3'], merged_nb.loc[merged_nb.index[i], 'F2_Score_x4'], merged_nb.loc[merged_nb.index[i], 'F2_Score_x5']] )

merged_nb.sort_values("Median_Score", ascending=False, inplace=True)
merged_nb

#Use threshold of 0.1
# Out:
#    Threshold  F2_Score_x1  Accuracy_x1  Recall_x1  Precision_x1  F2_Score_x2  \
# 0        0.1     0.445318     0.266208   0.844427      0.154060     0.480379
# 1        0.2     0.440621     0.280575   0.823577      0.154065     0.479237
# 2        0.3     0.437029     0.297213   0.803929      0.154671     0.476965
# 3        0.4     0.426334     0.331164   0.757418      0.155116     0.454998
# 4        0.5     0.408519     0.369290   0.695269      0.154174     0.253855
#
#    Accuracy_x2  Recall_x2  Precision_x2  F2_Score_x3  ...  Precision_x3  \
# 0     0.182281   0.965782      0.159573     0.484738  ...      0.158435
# 1     0.183632   0.961938      0.159363     0.484630  ...      0.158494
# 2     0.195788   0.947328      0.159730     0.484481  ...      0.158926
# 3     0.267682   0.843906      0.160020     0.473159  ...      0.159238
# 4     0.634885   0.298731      0.158571     0.396939  ...      0.162444
#
#    F2_Score_x4  Accuracy_x4  Recall_x4  Precision_x4  F2_Score_x5  \
# 0     0.473012     0.182220   0.965545      0.155574     0.481198
# 1     0.471772     0.184921   0.960396      0.155439     0.481136
# 2     0.471466     0.187070   0.958020      0.155523     0.480809
# 3     0.466955     0.195911   0.940198      0.154961     0.479171
# 4     0.451050     0.254666   0.859406      0.155500     0.455632
#
#    Accuracy_x5  Recall_x5  Precision_x5  Median_Score
# 0     0.156557   0.999608      0.156515      0.480379
# 1     0.156864   0.999216      0.156521      0.479237
# 2     0.158337   0.997255      0.156540      0.476965
# 3     0.161591   0.990588      0.156331      0.466955
# 4     0.230599   0.881961      0.155318      0.408519
#
# [5 rows x 22 columns]

# %% [markdown]
# 2. Optimizing Accuracy

# %%
#Kruskal-Wallis test
accuracyList=[]
for i in range(len(merged_nb['Accuracy_x1'])):
  accuracyList.append([merged_nb['Accuracy_x1'].values[i], merged_nb['Accuracy_x2'].values[i],  merged_nb['Accuracy_x3'].values[i],  merged_nb['Accuracy_x4'].values[i],  merged_nb['Accuracy_x5'].values[i]])

result = stats.kruskal(*accuracyList)
print(result)
# Out:
# KruskalResult(statistic=10.028307692307692, pvalue=0.039953532782523615)

# %%
#There is a statistically significant difference in the population medians

# %%
#Computing median accuracy across all five sliding windows for each combination
#of hyperparameters
for i in range(len(merged_nb['Accuracy_x1'])):
      merged_nb.loc[merged_nb.index[i], 'Median_Accuracy'] = statistics.median([merged_nb.loc[merged_nb.index[i], 'Accuracy_x1'],merged_nb.loc[merged_nb.index[i], 'Accuracy_x2'], merged_nb.loc[merged_nb.index[i], 'Accuracy_x3'], merged_nb.loc[merged_nb.index[i], 'Accuracy_x4'], merged_nb.loc[merged_nb.index[i], 'Accuracy_x5']] )

merged_nb.sort_values("Median_Accuracy", ascending=False, inplace=True)
merged_nb

#Use threshold of 0.5
# Out:
#    Threshold  F2_Score_x1  Accuracy_x1  Recall_x1  Precision_x1  F2_Score_x2  \
# 4        0.5     0.408519     0.369290   0.695269      0.154174     0.253855
# 3        0.4     0.426334     0.331164   0.757418      0.155116     0.454998
# 2        0.3     0.437029     0.297213   0.803929      0.154671     0.476965
# 1        0.2     0.440621     0.280575   0.823577      0.154065     0.479237
# 0        0.1     0.445318     0.266208   0.844427      0.154060     0.480379
#
#    Accuracy_x2  Recall_x2  Precision_x2  F2_Score_x3  ...  F2_Score_x4  \
# 4     0.634885   0.298731      0.158571     0.396939  ...     0.451050
# 3     0.267682   0.843906      0.160020     0.473159  ...     0.466955
# 2     0.195788   0.947328      0.159730     0.484481  ...     0.471466
# 1     0.183632   0.961938      0.159363     0.484630  ...     0.471772
# 0     0.182281   0.965782      0.159573     0.484738  ...     0.473012
#
#    Accuracy_x4  Recall_x4  Precision_x4  F2_Score_x5  Accuracy_x5  Recall_x5  \
# 4     0.254666   0.859406      0.155500     0.455632     0.230599   0.881961
# 3     0.195911   0.940198      0.154961     0.479171     0.161591   0.990588
# 2     0.187070   0.958020      0.155523     0.480809     0.158337   0.997255
# 1     0.184921   0.960396      0.155439     0.481136     0.156864   0.999216
# 0     0.182220   0.965545      0.155574     0.481198     0.156557   0.999608
#
#    Precision_x5  Median_Score  Median_Accuracy
# 4      0.155318      0.408519         0.369290
# 3      0.156331      0.466955         0.208804
# 2      0.156540      0.476965         0.187070
# 1      0.156521      0.479237         0.183632
# 0      0.156515      0.480379         0.182220
#
# [5 rows x 23 columns]

# %% [markdown]
# Random Forest

# %%
rfScores1 = pd.read_csv("/content/rfScores1.csv")
rfScores2 = pd.read_csv("/content/rfScores2.csv")
rfScores3 = pd.read_csv("/content/rfScores3.csv")
rfScores4 = pd.read_csv("/content/rfScores4.csv")
rfScores5 = pd.read_csv("/content/rfScores5.csv")

# %%
rfScores1 = rfScores1.drop(['Unnamed: 0'], axis=1)
rfScores2 = rfScores2.drop(['Unnamed: 0'], axis=1)
rfScores3 = rfScores3.drop(['Unnamed: 0'], axis=1)
rfScores4 = rfScores4.drop(['Unnamed: 0'], axis=1)
rfScores5 = rfScores5.drop(['Unnamed: 0'], axis=1)

# %%
merged_rfA = rfScores1.merge(rfScores2,on=['Threshold', 'n_Estimators', 'Max_depth'], suffixes=('_x1', '_x2'))
merged_rfB = merged_rfA.merge(rfScores3,on=['Threshold', 'n_Estimators', 'Max_depth'])
merged_rfC = merged_rfB.merge(rfScores4,on=['Threshold', 'n_Estimators', 'Max_depth'], suffixes=('_x3', '_x4'))
merged_rf = merged_rfC.merge(rfScores5,on=['Threshold', 'n_Estimators', 'Max_depth'])
merged_rf.rename(columns={'F2_Score': 'F2_Score_x5', 'Accuracy': 'Accuracy_x5', 'Recall': 'Recall_x5', 'Precision': 'Precision_x5'}, inplace=True)

# %%
merged_rf= merged_rf.loc[~( (merged_rf['Recall_x1'] == 0) | (merged_rf['Recall_x2'] ==0)| (merged_rf['Recall_x3'] ==0)| (merged_rf['Recall_x4'] ==0)| (merged_rf['Recall_x5'] ==0)| (merged_rf['Precision_x1'] ==0)| (merged_rf['Precision_x2'] ==0)| (merged_rf['Precision_x3'] ==0)| (merged_rf['Precision_x4'] ==0)| (merged_rf['Precision_x5'] ==0) |(merged_rf['Recall_x1'] == 1) | (merged_rf['Recall_x2'] ==1)| (merged_rf['Recall_x3'] ==1)| (merged_rf['Recall_x4'] ==1)| (merged_rf['Recall_x5'] ==1)| (merged_rf['Precision_x1'] ==1)| (merged_rf['Precision_x2'] ==1)| (merged_rf['Precision_x3'] ==1)| (merged_rf['Precision_x4'] ==1)| (merged_rf['Precision_x5'] ==1)       ),:]

# %% [markdown]
# 1. Optimizing F2-Score

# %%
#Kruskal-Wallis test
f2List=[]
for i in range(len(merged_rf['F2_Score_x1'])):
  f2List.append([merged_rf['F2_Score_x1'].values[i], merged_rf['F2_Score_x2'].values[i],  merged_rf['F2_Score_x3'].values[i],  merged_rf['F2_Score_x4'].values[i],  merged_rf['F2_Score_x5'].values[i]])

result = stats.kruskal(*f2List)
print(result)
# Out:
# KruskalResult(statistic=174.03249088517464, pvalue=3.4563177331764504e-16)

# %%
#There is a statistically significant difference in the population medians

# %%
#Computing median F-2 Score across all five sliding windows for each combination
#of hyperparameters
for i in range(len(merged_rf['F2_Score_x1'])):
      merged_rf.loc[merged_rf.index[i], 'Median_Score'] = statistics.median([merged_rf.loc[merged_rf.index[i], 'F2_Score_x1'],merged_rf.loc[merged_rf.index[i], 'F2_Score_x2'], merged_rf.loc[merged_rf.index[i], 'F2_Score_x3'], merged_rf.loc[merged_rf.index[i], 'F2_Score_x4'], merged_rf.loc[merged_rf.index[i], 'F2_Score_x5']] )

merged_rf.sort_values("Median_Score", ascending=False, inplace=True)
merged_rf

#The optimal hyperparameters are n_Estimators=75, max_depth=10, and threshold=0.2
# Out:
#      n_Estimators  Max_depth  Threshold  F2_Score_x1  Accuracy_x1  Recall_x1  \
# 154            75         10        0.2     0.473211     0.158767   0.991580
# 100            50         10        0.2     0.472888     0.160302   0.989575
# 46             25         10        0.2     0.471851     0.169450   0.979952
# 208           100         10        0.2     0.473606     0.157478   0.993585
# 29             25          4        0.3     0.474622     0.153057   0.999599
# 38             25          5        0.3     0.474110     0.155513   0.996391
# 92             50          5        0.3     0.474530     0.153794   0.998797
# 200           100          5        0.3     0.474530     0.153794   0.998797
# 146            75          5        0.3     0.474149     0.153549   0.997995
# 101            50         10        0.3     0.438049     0.299914   0.804330
# 12      0.764366   0.120392      0.161409      0.244443
# 48      0.717461   0.200000      0.166016      0.192134
# 192     0.814956   0.046667      0.169516      0.189127
# 30      0.808755   0.050588      0.156744      0.181114
# 138     0.814526   0.048235      0.171548      0.172048
# 183     0.816859   0.052549      0.191155      0.170826
# 39      0.816675   0.050196      0.184971      0.166248
# 129     0.813728   0.056078      0.185714      0.165599
# 102     0.753622   0.136078      0.160872      0.152574
# 210     0.762893   0.124706      0.163244      0.149336
# 201     0.817043   0.043922      0.171254      0.148605
# 75      0.821218   0.043922      0.191126      0.148104
# 156     0.769094   0.123922      0.171460      0.146918
# 21      0.815263   0.051765      0.182573      0.145755
# 147     0.820113   0.038431      0.170139      0.132722
# 93      0.823612   0.036078      0.181460      0.116447
# 84      0.813667   0.043137      0.156028      0.116083
# 49      0.809369   0.050980      0.159509      0.029817
# 157     0.833804   0.015294      0.165957      0.014269
# 103     0.828524   0.025490      0.174263      0.014118
# 211     0.833436   0.015686      0.164609      0.012689
# 4       0.842215   0.003529      0.236842      0.007686
# 13      0.842215   0.003529      0.236842      0.007207
# 175     0.842092   0.003529      0.225000      0.005420
# 166     0.842338   0.003529      0.250000      0.005409
# 40      0.842092   0.003922      0.238095      0.005408
# 67      0.842952   0.002353      0.300000      0.004927
# 112     0.842338   0.003529      0.250000      0.004919
# 31      0.842399   0.003529      0.257143      0.004815
# 58      0.842890   0.002353      0.285714      0.004763
# 121     0.842461   0.003529      0.264706      0.004397
# 139     0.842768   0.003137      0.296296      0.003855
# 85      0.842890   0.001961      0.263158      0.002446
#
# [49 rows x 24 columns]

# %% [markdown]
# 2. Optimizing Accuracy

# %%
#Kruskal-Wallis test
accuracyList=[]
for i in range(len(merged_rf['Accuracy_x1'])):
  accuracyList.append([merged_rf['Accuracy_x1'].values[i], merged_rf['Accuracy_x2'].values[i],  merged_rf['Accuracy_x3'].values[i],  merged_rf['Accuracy_x4'].values[i],  merged_rf['Accuracy_x5'].values[i]])

result = stats.kruskal(*accuracyList)
print(result)
# Out:
# KruskalResult(statistic=171.81276579771549, pvalue=7.840391279168154e-16)

# %%
#There is a statistically significant difference in the population medians

# %%
#Computing median accuracy across all five sliding windows for each combination
#of hyperparameters
for i in range(len(merged_rf['Accuracy_x1'])):
      merged_rf.loc[merged_rf.index[i], 'Median_Accuracy'] = statistics.median([merged_rf.loc[merged_rf.index[i], 'Accuracy_x1'],merged_rf.loc[merged_rf.index[i], 'Accuracy_x2'], merged_rf.loc[merged_rf.index[i], 'Accuracy_x3'], merged_rf.loc[merged_rf.index[i], 'Accuracy_x4'], merged_rf.loc[merged_rf.index[i], 'Accuracy_x5']] )

merged_rf.sort_values("Median_Accuracy", ascending=False, inplace=True)
merged_rf

#Use n_Estimators=25, max_depth=5, threshold=0.5
# Out:
#      n_Estimators  Max_depth  Threshold  F2_Score_x1  Accuracy_x1  Recall_x1  \
# 40             25          5        0.5     0.057180     0.819376   0.048917
# 139            75          4        0.5     0.038407     0.821893   0.032478
# 85             50          4        0.5     0.060163     0.812009   0.052125
# 13    0.003529      0.236842      0.007207         0.838286
# 67    0.002353      0.300000      0.004927         0.838286
# 112   0.003529      0.250000      0.004919         0.838286
# 58    0.002353      0.285714      0.004763         0.838286
# 211   0.015686      0.164609      0.012689         0.834234
# 157   0.015294      0.165957      0.014269         0.833804
# 103   0.025490      0.174263      0.014118         0.831778
# 49    0.050980      0.159509      0.029817         0.824349
# 93    0.036078      0.181460      0.116447         0.776400
# 84    0.043137      0.156028      0.116083         0.768971
# 147   0.038431      0.170139      0.132722         0.759209
# 21    0.051765      0.182573      0.145755         0.751473
# 156   0.123922      0.171460      0.146918         0.749693
# 201   0.043922      0.171254      0.148605         0.744843
# 102   0.136078      0.160872      0.152574         0.744045
# 75    0.043922      0.191126      0.148104         0.741650
# 210   0.124706      0.163244      0.149336         0.740914
# 129   0.056078      0.185714      0.165599         0.732809
# 183   0.052549      0.191155      0.170826         0.723662
# 39    0.050196      0.184971      0.166248         0.722127
# 138   0.048235      0.171548      0.172048         0.721083
# 48    0.200000      0.166016      0.192134         0.717461
# 30    0.050588      0.156744      0.181114         0.711321
# 192   0.046667      0.169516      0.189127         0.710216
# 66    0.096863      0.164557      0.245743         0.665336
# 12    0.120392      0.161409      0.244443         0.665152
# 120   0.100784      0.162247      0.265693         0.637954
# 174   0.116863      0.165464      0.277919         0.619290
# 47    0.472157      0.156242      0.336200         0.518173
# 209   0.410980      0.158740      0.348774         0.496869
# 155   0.390980      0.155344      0.351635         0.493554
# 101   0.410588      0.156948      0.364631         0.482073
# 146   0.367451      0.157532      0.396145         0.432650
# 200   0.389412      0.153930      0.399168         0.421353
# 92    0.343529      0.156373      0.405171         0.408829
# 38    0.312549      0.158733      0.423440         0.356029
# 29    0.393725      0.152375      0.434197         0.329936
# 46    0.762745      0.156830      0.451973         0.274374
# 154   0.749020      0.155944      0.453693         0.267129
# 100   0.733333      0.155613      0.452106         0.265349
# 208   0.755686      0.157332      0.450262         0.264735
#
# [49 rows x 25 columns]

# %% [markdown]
# Light GBM

# %%
bstScores1 = pd.read_csv("/content/bstScores1.csv")
bstScores2 = pd.read_csv("/content/bstScores2.csv")
bstScores3 = pd.read_csv("/content/bstScores3.csv")
bstScores4 = pd.read_csv("/content/bstScores4.csv")
bstScores5 = pd.read_csv("/content/bstScores5.csv")

# %%
bstScores1 = bstScores1.drop(['Unnamed: 0'], axis=1)
bstScores2 = bstScores2.drop(['Unnamed: 0'], axis=1)
bstScores3 = bstScores3.drop(['Unnamed: 0'], axis=1)
bstScores4 = bstScores4.drop(['Unnamed: 0'], axis=1)
bstScores5 = bstScores5.drop(['Unnamed: 0'], axis=1)

# %%
merged_bstA = bstScores1.merge(bstScores2,on=['Threshold', 'Num_Leaves', 'Reg_Alpha', 'Reg_Lambda', 'Min_Data'], suffixes=('_x1', '_x2'))
merged_bstB = merged_bstA.merge(bstScores3,on=['Threshold', 'Num_Leaves', 'Reg_Alpha', 'Reg_Lambda', 'Min_Data'])
merged_bstC = merged_bstB.merge(bstScores4,on=['Threshold', 'Num_Leaves', 'Reg_Alpha', 'Reg_Lambda', 'Min_Data'], suffixes=('_x3', '_x4'))
merged_bst = merged_bstC.merge(bstScores5,on=['Threshold', 'Num_Leaves', 'Reg_Alpha', 'Reg_Lambda', 'Min_Data'])
merged_bst.rename(columns={'F2_Score': 'F2_Score_x5', 'Accuracy': 'Accuracy_x5', 'Recall': 'Recall_x5', 'Precision': 'Precision_x5'}, inplace=True)

# %%
merged_bst= merged_bst.loc[~( (merged_bst['Recall_x1'] == 0) | (merged_bst['Recall_x2'] ==0)| (merged_bst['Recall_x3'] ==0)| (merged_bst['Recall_x4'] ==0)| (merged_bst['Recall_x5'] ==0)| (merged_bst['Precision_x1'] ==0)| (merged_bst['Precision_x2'] ==0)| (merged_bst['Precision_x3'] ==0)| (merged_bst['Precision_x4'] ==0)| (merged_bst['Precision_x5'] ==0) |(merged_bst['Recall_x1'] == 1) | (merged_bst['Recall_x2'] ==1)| (merged_bst['Recall_x3'] ==1)| (merged_bst['Recall_x4'] ==1)| (merged_bst['Recall_x5'] ==1)| (merged_bst['Precision_x1'] ==1)| (merged_bst['Precision_x2'] ==1)| (merged_bst['Precision_x3'] ==1)| (merged_bst['Precision_x4'] ==1)| (merged_bst['Precision_x5'] ==1)       ),:]

# %% [markdown]
# 1. Optimizing F2-Score

# %%
#Kruskal-Wallis test
f2List=[]
for i in range(len(merged_bst['F2_Score_x1'])):
  f2List.append([merged_bst['F2_Score_x1'].values[i], merged_bst['F2_Score_x2'].values[i],  merged_bst['F2_Score_x3'].values[i],  merged_bst['F2_Score_x4'].values[i],  merged_bst['F2_Score_x5'].values[i]])

result = stats.kruskal(*f2List)
print(result)
# Out:
# KruskalResult(statistic=649.6997578024121, pvalue=5.741978503936958e-67)

# %%
#There is a statistically significant difference in the population medians

# %%
#Computing median F-2 Score across all five sliding windows for each combination
#of hyperparameters
for i in range(len(merged_bst['F2_Score_x1'])):
      merged_bst.loc[merged_bst.index[i], 'Median_Score'] = statistics.median([merged_bst.loc[merged_bst.index[i], 'F2_Score_x1'],merged_bst.loc[merged_bst.index[i], 'F2_Score_x2'], merged_bst.loc[merged_bst.index[i], 'F2_Score_x3'], merged_bst.loc[merged_bst.index[i], 'F2_Score_x4'], merged_bst.loc[merged_bst.index[i], 'F2_Score_x5']] )

merged_bst.sort_values("Median_Score", ascending=False, inplace=True)
merged_bst

#The optimal hyperparameters are num_leaves=7, reg_alpha=0.5, reg_lambda=0.1, min_data=100, threshold=0.1
# Out:
#      Num_Leaves  Reg_Alpha  Reg_Lambda  Min_Data  Threshold  F2_Score_x1  \
# 72            7        0.5         0.1       100        0.1     0.469255
# 18            7        0.1         0.1       100        0.1     0.469529
# 81            7        0.5         0.5         5        0.1     0.467880
# 90            7        0.5         0.5        30        0.1     0.467028
# 36            7        0.1         0.5        30        0.1     0.468127
# ..          ...        ...         ...       ...        ...          ...
# 204          31        0.5         0.5        30        0.7     0.001000
# 195          31        0.5         0.5         5        0.7     0.000501
# 186          31        0.5         0.1       100        0.7     0.001997
# 159          31        0.1         0.5       100        0.7     0.000500
# 132          31        0.1         0.1       100        0.7     0.000500
#
#      Accuracy_x1  Recall_x1  Precision_x1  F2_Score_x2  ...  Precision_x3  \
# 72      0.194131   0.954691      0.154671     0.483261  ...      0.158556
# 18      0.188667   0.959503      0.154317     0.482594  ...      0.158646
# 81      0.195420   0.950281      0.154387     0.485061  ...      0.158178
# 90      0.195788   0.947875      0.154177     0.483535  ...      0.158140
# 36      0.195174   0.951083      0.154437     0.484195  ...      0.157971
# ..           ...        ...           ...          ...  ...           ...
# 204     0.845715   0.000802      0.086957     0.008050  ...      0.145161
# 195     0.846636   0.000401      0.166667     0.011797  ...      0.163522
# 186     0.844917   0.001604      0.100000     0.009946  ...      0.134831
# 159     0.845715   0.000401      0.047619     0.009475  ...      0.176991
# 132     0.846083   0.000401      0.066667     0.009018  ...      0.156863
#
#      F2_Score_x4  Accuracy_x4  Recall_x4  Precision_x4  F2_Score_x5  \
# 72      0.477909     0.157908   0.996436      0.155088     0.481379
# 18      0.477331     0.158030   0.994851      0.154937     0.481234
# 81      0.477781     0.156434   0.997228      0.154944     0.480733
# 90      0.477790     0.156987   0.996832      0.154988     0.480333
# 36      0.477917     0.157417   0.996832      0.155055     0.480700
# ..           ...          ...        ...           ...          ...
# 204     0.015532     0.836567   0.012673      0.159204     0.026168
# 195     0.020253     0.833620   0.016634      0.156134     0.037027
# 186     0.018861     0.835093   0.015446      0.163180     0.029287
# 159     0.019346     0.835278   0.015842      0.168067     0.015411
# 132     0.015974     0.834971   0.013069      0.144105     0.019670
#
#      Accuracy_x5  Recall_x5  Precision_x5  Median_Score
# 72      0.157171   0.999608      0.156611      0.481379
# 18      0.156680   0.999608      0.156534      0.481234
# 81      0.157048   0.998039      0.156423      0.480499
# 90      0.158276   0.996078      0.156404      0.479081
# 36      0.157969   0.997255      0.156483      0.478770
# ..           ...        ...           ...           ...
# 204     0.831225   0.021569      0.177994      0.012845
# 195     0.824411   0.030980      0.168803      0.012401
# 186     0.827419   0.024314      0.161039      0.009946
# 159     0.836198   0.012549      0.175824      0.009581
# 132     0.834848   0.016078      0.184685      0.009018
#
# [140 rows x 26 columns]

# %% [markdown]
# 2. Optimizing Accuracy

# %%
#Kruskal-Wallis test
accuracyList=[]
for i in range(len(merged_bst['Accuracy_x1'])):
  accuracyList.append([merged_bst['Accuracy_x1'].values[i], merged_bst['Accuracy_x2'].values[i],  merged_bst['Accuracy_x3'].values[i],  merged_bst['Accuracy_x4'].values[i],  merged_bst['Accuracy_x5'].values[i]])

result = stats.kruskal(*accuracyList)
print(result)
# Out:
# KruskalResult(statistic=647.0332844527268, pvalue=1.6451521323297722e-66)

# %%
#There is a statistically significant difference in the population medians

# %%
#Computing median accuracy across all five sliding windows for each combination
#of hyperparameters
for i in range(len(merged_bst['Accuracy_x1'])):
      merged_bst.loc[merged_bst.index[i], 'Median_Accuracy'] = statistics.median([merged_bst.loc[merged_bst.index[i], 'Accuracy_x1'],merged_bst.loc[merged_bst.index[i], 'Accuracy_x2'], merged_bst.loc[merged_bst.index[i], 'Accuracy_x3'], merged_bst.loc[merged_bst.index[i], 'Accuracy_x4'], merged_bst.loc[merged_bst.index[i], 'Accuracy_x5']] )

merged_bst.sort_values("Median_Accuracy", ascending=False, inplace=True)
merged_bst

#The optimal hyperparameters are num_leaves=31, reg_alpha=0.5, reg_lambda=0.5, min_data=100, threshold=0.7
# Out:
#      Num_Leaves  Reg_Alpha  Reg_Lambda  Min_Data  Threshold  F2_Score_x1  \
# 213          31        0.5         0.5       100        0.7     0.000500
# 159          31        0.1         0.5       100        0.7     0.000500
# 123          31        0.1         0.1        30        0.7     0.000999
# 186          31        0.5         0.1       100        0.7     0.001997
# 132          31        0.1         0.1       100        0.7     0.000500
# ..          ...        ...         ...       ...        ...          ...
# 9             7        0.1         0.1        30        0.1     0.467475
# 90            7        0.5         0.5        30        0.1     0.467028
# 81            7        0.5         0.5         5        0.1     0.467880
# 18            7        0.1         0.1       100        0.1     0.469529
# 72            7        0.5         0.1       100        0.1     0.469255
#
#      Accuracy_x1  Recall_x1  Precision_x1  F2_Score_x2  ...  F2_Score_x4  \
# 213     0.846022   0.000401      0.062500     0.015033  ...     0.014574
# 159     0.845715   0.000401      0.047619     0.009475  ...     0.019346
# 123     0.844855   0.000802      0.054054     0.013183  ...     0.017464
# 186     0.844917   0.001604      0.100000     0.009946  ...     0.018861
# 132     0.846083   0.000401      0.066667     0.009018  ...     0.015974
# ..           ...        ...           ...          ...  ...          ...
# 9       0.199411   0.946271      0.154592     0.484165  ...     0.477919
# 90      0.195788   0.947875      0.154177     0.483535  ...     0.477790
# 81      0.195420   0.950281      0.154387     0.485061  ...     0.477781
# 18      0.188667   0.959503      0.154317     0.482594  ...     0.477331
# 72      0.194131   0.954691      0.154671     0.483261  ...     0.477909
#
#      Accuracy_x4  Recall_x4  Precision_x4  F2_Score_x5  Accuracy_x5  \
# 213     0.836874   0.011881      0.156250     0.025193     0.830366
# 159     0.835278   0.015842      0.168067     0.015411     0.836198
# 123     0.836690   0.014257      0.173913     0.046885     0.820788
# 186     0.835093   0.015446      0.163180     0.029287     0.827419
# 132     0.834971   0.013069      0.144105     0.019670     0.834848
# ..           ...        ...           ...          ...          ...
# 9       0.158460   0.996040      0.155132     0.480638     0.158276
# 90      0.156987   0.996832      0.154988     0.480333     0.158276
# 81      0.156434   0.997228      0.154944     0.480733     0.157048
# 18      0.158030   0.994851      0.154937     0.481234     0.156680
# 72      0.157908   0.996436      0.155088     0.481379     0.157171
#
#      Recall_x5  Precision_x5  Median_Score  Median_Accuracy
# 213   0.020784      0.166144      0.014574         0.836567
# 159   0.012549      0.175824      0.009581         0.836198
# 123   0.039608      0.176883      0.015266         0.835830
# 186   0.024314      0.161039      0.009946         0.835093
# 132   0.016078      0.184685      0.009018         0.834971
# ..         ...           ...           ...              ...
# 9     0.996863      0.156489      0.478478         0.173256
# 90    0.996078      0.156404      0.479081         0.172274
# 81    0.998039      0.156423      0.480499         0.170739
# 18    0.999608      0.156534      0.481234         0.169143
# 72    0.999608      0.156611      0.481379         0.167792
#
# [140 rows x 27 columns]
