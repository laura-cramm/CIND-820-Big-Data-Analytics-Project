# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import TimeSeriesSplit

# %%
q2features_trainvalid = pd.read_pickle("q2features_trainvalid.pickle")

# %%
#Sorting data by participant sequence number (by date) :
q2features_trainvalid = q2features_trainvalid.sort_values(by = ["SEQNO"], ascending=False)

# %% [markdown]
# Overfitting occurs when a machine learning algorithm performs poorly on data that it was not trained on. Cross-validation can help prevent overfitting.
#
# All BRFSS surveys were not conducted on the same date; there is a time series aspect to the dataset. Sliding window validation was therefore conducted, not the standard k-fold cross-validation methodology. This sliding window validation method ensures that the validation dataset always occurs chronologically after the training dataset.; the model cannot 'see the future' (which would artificially improve model performance).

# %%
#Splitting data for sliding window cross-validation
tscv = TimeSeriesSplit(n_splits=5)

tscv.split(q2features_trainvalid)

# %%
q2_train_index = []
q2_valid_index = []

#Iterating over tscv object to obtain indices that give train/validate splits
for train_index, valid_index in tscv.split(q2features_trainvalid):
  q2_train_index.append(train_index)
  q2_valid_index.append(valid_index)

# %%
#Using these indices to split data into five training and five validation
#sets
q2features_train_1 = q2features_trainvalid.iloc[q2_train_index[0], :]
q2features_valid_1 = q2features_trainvalid.iloc[q2_valid_index[0], :]

q2features_train_2 = q2features_trainvalid.iloc[q2_train_index[1], :]
q2features_valid_2 = q2features_trainvalid.iloc[q2_valid_index[1], :]

q2features_train_3 = q2features_trainvalid.iloc[q2_train_index[2], :]
q2features_valid_3 = q2features_trainvalid.iloc[q2_valid_index[2], :]

q2features_train_4 = q2features_trainvalid.iloc[q2_train_index[3], :]
q2features_valid_4 = q2features_trainvalid.iloc[q2_valid_index[3], :]

q2features_train_5 = q2features_trainvalid.iloc[q2_train_index[4], :]
q2features_valid_5 = q2features_trainvalid.iloc[q2_valid_index[4], :]

# %%
#Also splitting the labels for the target variable
q2target_train_1 = q2target_trainvalid.iloc[q2_train_index[0]]
q2target_valid_1 = q2target_trainvalid.iloc[q2_valid_index[0]]

q2target_train_2 = q2target_trainvalid.iloc[q2_train_index[1]]
q2target_valid_2 = q2target_trainvalid.iloc[q2_valid_index[1]]

q2target_train_3 = q2target_trainvalid.iloc[q2_train_index[2]]
q2target_valid_3 = q2target_trainvalid.iloc[q2_valid_index[2]]

q2target_train_4 = q2target_trainvalid.iloc[q2_train_index[3]]
q2target_valid_4 = q2target_trainvalid.iloc[q2_valid_index[3]]

q2target_train_5 = q2target_trainvalid.iloc[q2_train_index[4]]
q2target_valid_5 = q2target_trainvalid.iloc[q2_valid_index[4]]

# %%
q2features_train_1.to_pickle('q2features_train_1.pickle')
q2features_train_2.to_pickle('q2features_train_2.pickle')
q2features_train_3.to_pickle('q2features_train_3.pickle')
q2features_train_4.to_pickle('q2features_train_4.pickle')
q2features_train_5.to_pickle('q2features_train_5.pickle')

# %%
q2features_valid_1.to_pickle('q2features_valid_1.pickle')
q2features_valid_2.to_pickle('q2features_valid_2.pickle')
q2features_valid_3.to_pickle('q2features_valid_3.pickle')
q2features_valid_4.to_pickle('q2features_valid_4.pickle')
q2features_valid_5.to_pickle('q2features_valid_5.pickle')

# %%
q2target_train_1.to_pickle('q2target_train_1.pickle')
q2target_train_2.to_pickle('q2target_train_2.pickle')
q2target_train_3.to_pickle('q2target_train_3.pickle')
q2target_train_4.to_pickle('q2target_train_4.pickle')
q2target_train_5.to_pickle('q2target_train_5.pickle')

# %%
q2target_valid_1.to_pickle('q2target_valid_1.pickle')
q2target_valid_2.to_pickle('q2target_valid_2.pickle')
q2target_valid_3.to_pickle('q2target_valid_3.pickle')
q2target_valid_4.to_pickle('q2target_valid_4.pickle')
q2target_valid_5.to_pickle('q2target_valid_5.pickle')
